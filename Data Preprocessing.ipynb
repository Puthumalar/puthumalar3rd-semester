# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import Normalizer
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
File = pd.read_csv("Laptop_Data.csv")

# %%
File
# Out:
#     Unnamed: 0                                            Product  \
# 0            0   JioBook 11(2023) Ultimate Learning Partner, N...
# 1            1   HP Victus 15-FA1313TX Gaming Laptop (Intel Co...
# 2            2   HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...
# 3            3   Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...
# 4            4   Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...
# 5            5   Acer Aspire Lite AL15-52 Standard Laptop (Int...
# 6            6   Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 7            7   HP 15s-fr5012TU Standard Laptop (Intel Core i...
# 8            8   Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 9            9   Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...
# 10          10   Walker NU14A1 14.1 inches Gemini Celeron N 40...
# 11          11   Dell Inspiron 3520 Laptop, Intel Core i3-1215...
#
#                                                 Price  \
# ...

# %%
File.drop("Unnamed: 0", axis = 1)
# Out:
#                                               Product  \
# 0    JioBook 11(2023) Ultimate Learning Partner, N...
# 1    HP Victus 15-FA1313TX Gaming Laptop (Intel Co...
# 2    HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...
# 3    Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...
# 4    Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...
# 5    Acer Aspire Lite AL15-52 Standard Laptop (Int...
# 6    Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 7    HP 15s-fr5012TU Standard Laptop (Intel Core i...
# 8    Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 9    Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...
# 10   Walker NU14A1 14.1 inches Gemini Celeron N 40...
# 11   Dell Inspiron 3520 Laptop, Intel Core i3-1215...
#
#                                                 Price  \
# 0   <span class="jm-heading-xxs jm-mb-xxs">₹15,499...
# 1   <span class="jm-heading-xxs jm-mb-xxs">₹58,999...
# 2   <span class="jm-heading-xxs jm-mb-xxs">₹63,999...
# ...

# %%
File["Offer"] = File["Offer"].str.strip('<span class="jm-badge">% OFF</span>').astype(str)

# %%
File
# Out:
#     Unnamed: 0                                            Product  \
# 0            0   JioBook 11(2023) Ultimate Learning Partner, N...
# 1            1   HP Victus 15-FA1313TX Gaming Laptop (Intel Co...
# 2            2   HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...
# 3            3   Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...
# 4            4   Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...
# 5            5   Acer Aspire Lite AL15-52 Standard Laptop (Int...
# 6            6   Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 7            7   HP 15s-fr5012TU Standard Laptop (Intel Core i...
# 8            8   Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 9            9   Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...
# 10          10   Walker NU14A1 14.1 inches Gemini Celeron N 40...
# 11          11   Dell Inspiron 3520 Laptop, Intel Core i3-1215...
#
#                                                 Price     Offer
# ...

# %%
 File["Price"] = File["Price"].str.strip('<span class="jm-heading-xxs jm-mb-xxs">₹</span>').astype(str)

# %%
File
# Out:
#     Unnamed: 0                                            Product      Price  \
# 0            0   JioBook 11(2023) Ultimate Learning Partner, N...  15,499.00
# 1            1   HP Victus 15-FA1313TX Gaming Laptop (Intel Co...  58,999.00
# 2            2   HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...  63,999.00
# 3            3   Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...  71,990.00
# 4            4   Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...  62,999.00
# 5            5   Acer Aspire Lite AL15-52 Standard Laptop (Int...  30,990.00
# 6            6   Dell Inspiron 15 3520 Notebook Laptop (Intel ...  36,999.00
# 7            7   HP 15s-fr5012TU Standard Laptop (Intel Core i...  34,990.00
# 8            8   Dell Inspiron 15 3520 Notebook Laptop (Intel ...  49,999.00
# 9            9   Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...  87,990.00
# 10          10   Walker NU14A1 14.1 inches Gemini Celeron N 40...  12,990.00
# ...

# %% [markdown]
# # Categorical Data

# %%
Price_Category = pd.DataFrame({"Price" : ["15,499.00", "58,999.00", "63,999.00", "71,990.00", "62,999.00", "30,990.00", "36,999.00", "34,990.00", "49,999.00", "87,990.00", "12,990.00", "38,990.00"], 
                           "Range" : ["LOW", "MID", "HIGH", "HIGH", "HIGH", "LOW", "LOW","LOW","MID", "HIGH", "LOW", "LOW"]})

# %%
Price_Category
# Out:
#         Price Range
# 0   15,499.00   LOW
# 1   58,999.00   MID
# 2   63,999.00  HIGH
# 3   71,990.00  HIGH
# 4   62,999.00  HIGH
# 5   30,990.00   LOW
# 6   36,999.00   LOW
# 7   34,990.00   LOW
# 8   49,999.00   MID
# 9   87,990.00  HIGH
# 10  12,990.00   LOW
# 11  38,990.00   LOW

# %%
publish = pd.DataFrame(File["Product"],columns = ["Product"])

# %%
publish
# Out:
#                                               Product
# 0    JioBook 11(2023) Ultimate Learning Partner, N...
# 1    HP Victus 15-FA1313TX Gaming Laptop (Intel Co...
# 2    HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...
# 3    Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...
# 4    Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...
# 5    Acer Aspire Lite AL15-52 Standard Laptop (Int...
# 6    Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 7    HP 15s-fr5012TU Standard Laptop (Intel Core i...
# 8    Dell Inspiron 15 3520 Notebook Laptop (Intel ...
# 9    Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...
# 10   Walker NU14A1 14.1 inches Gemini Celeron N 40...
# 11   Dell Inspiron 3520 Laptop, Intel Core i3-1215...

# %%
publish["Range"] = Price_Category["Range"]

# %%
publish
# Out:
#                                               Product Range
# 0    JioBook 11(2023) Ultimate Learning Partner, N...   LOW
# 1    HP Victus 15-FA1313TX Gaming Laptop (Intel Co...   MID
# 2    HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...  HIGH
# 3    Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...  HIGH
# 4    Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...  HIGH
# 5    Acer Aspire Lite AL15-52 Standard Laptop (Int...   LOW
# 6    Dell Inspiron 15 3520 Notebook Laptop (Intel ...   LOW
# 7    HP 15s-fr5012TU Standard Laptop (Intel Core i...   LOW
# 8    Dell Inspiron 15 3520 Notebook Laptop (Intel ...   MID
# 9    Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...  HIGH
# 10   Walker NU14A1 14.1 inches Gemini Celeron N 40...   LOW
# 11   Dell Inspiron 3520 Laptop, Intel Core i3-1215...   LOW

# %%
print(publish.columns)
# Out:
# Index(['Product', 'Range'], dtype='object')

# %%
publish
# Out:
#                                               Product Range
# 0    JioBook 11(2023) Ultimate Learning Partner, N...   LOW
# 1    HP Victus 15-FA1313TX Gaming Laptop (Intel Co...   MID
# 2    HP Victus 15-fb0178AX Gaming Laptop (AMD Ryze...  HIGH
# 3    Apple MGN63HNA MacBook Air (Apple M1 Chip/8GB...  HIGH
# 4    Asus TUF A15 FA506NFR-HN259WS Gaming Laptop (...  HIGH
# 5    Acer Aspire Lite AL15-52 Standard Laptop (Int...   LOW
# 6    Dell Inspiron 15 3520 Notebook Laptop (Intel ...   LOW
# 7    HP 15s-fr5012TU Standard Laptop (Intel Core i...   LOW
# 8    Dell Inspiron 15 3520 Notebook Laptop (Intel ...   MID
# 9    Apple MLXW3HNA MacBook Air (Apple M2 Chip/8GB...  HIGH
# 10   Walker NU14A1 14.1 inches Gemini Celeron N 40...   LOW
# 11   Dell Inspiron 3520 Laptop, Intel Core i3-1215...   LOW

# %% [markdown]
# # Feature Scaling

# %%
Test_Data = pd.DataFrame({'X' : np.random.randint(-1, 100, 1000), 
                          'Y' : np.random.randint(-50, 50, 1000), 
                          'Z' : np.random.randint(-200,200,1000)})

# %%
Test_Data
# Out:
#       X   Y    Z
# 0    54 -14 -181
# 1    74 -14  -23
# 2     2  19   97
# 3    46  15   80
# 4    59 -50  185
# ..   ..  ..  ...
# 995  60 -17  188
# 996   2  19 -122
# 997  55   1 -114
# 998  60 -28 -162
# 999  51 -22   55
#
# [1000 rows x 3 columns]

# %%
pl = plt.axes(projection = "3d")
pl.scatter3D(Test_Data.X, Test_Data.Y, Test_Data.Z)
plt.figure()

# %%
nm = Normalizer()

# %%
Normal_Data = nm.fit_transform(Test_Data)

# %%
Normal_Data
# Out:
# array([[ 0.28510833, -0.07391698, -0.95564089],
#        [ 0.93972516, -0.17778584, -0.29207674],
#        [ 0.0202299 ,  0.19218409,  0.98115036],
#        ...,
#        [ 0.43451455,  0.00790026, -0.90063016],
#        [ 0.34284035, -0.15999216, -0.92566895],
#        [ 0.65245351, -0.28145053,  0.70362633]])

# %%
Normal_df = pd.DataFrame(Normal_Data,columns = ['A','B','C'])

# %%
pl = plt.axes(projection = "3d")
pl.scatter3D(Normal_df.A, Normal_df.B, Normal_df.C)
plt.figure()

# %% [markdown]
# # Missing values

# %%
data = {"A" : [1,2,3,4,5],
        "B" : [10,40,np.nan,80,60],
        "C" : [np.nan,np.nan,100,50,40]}

# %%
Df = pd.DataFrame(data)

# %%
Df
# Out:
#    A     B      C
# 0  1  10.0    NaN
# 1  2  40.0    NaN
# 2  3   NaN  100.0
# 3  4  80.0   50.0
# 4  5  60.0   40.0

# %%
Df.isnull()
# Out:
#        A      B      C
# 0  False  False   True
# 1  False  False   True
# 2  False   True  False
# 3  False  False  False
# 4  False  False  False

# %%
SM = SimpleImputer(missing_values = np.nan, strategy = 'mean')

# %%
SM
# Out:
# SimpleImputer()

# %%
SM.fit(Df)
# Out:
# SimpleImputer()

# %%
SM.transform(Df)
# Out:
# array([[  1.        ,  10.        ,  63.33333333],
#        [  2.        ,  40.        ,  63.33333333],
#        [  3.        ,  47.5       , 100.        ],
#        [  4.        ,  80.        ,  50.        ],
#        [  5.        ,  60.        ,  40.        ]])
